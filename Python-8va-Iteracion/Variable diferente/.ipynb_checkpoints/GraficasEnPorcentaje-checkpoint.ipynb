# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
CNRS0 = pd.read_csv('CNRS0')
CNRS20 = pd.read_csv('CNRS20')
CNRS40 = pd.read_csv('CNRS40')
CNRS60 = pd.read_csv('CNRS60')
CNRS80 = pd.read_csv('CNRS80')
CNRS100 = pd.read_csv('CNRS100')

# %%
display(CNRS0)
# Out:
#        CNR1s     CNR2s     CNR3s      CNR4s      CNR5s
# 0        NaN       NaN       NaN        NaN        NaN
# 1   4.252514  5.928123  7.027968   8.294861   9.938147
# 2   4.895195  6.964291  8.647864  10.095716  12.391324
# 3   5.246293  7.518328  9.388033  11.101251  13.690928
# 4   4.921705  7.199142  9.028315  10.969370  13.895316
# 5   4.743920  6.625298  8.631735  10.696937  13.457942
# 6   4.283604  6.460308  8.229885   9.878335  12.750237
# 7   3.890999  5.846035  7.488481   9.077206  11.875209
# 8   3.235022  4.634880  6.199692   7.574864   9.779323
# 9   2.386658  3.902449  5.004236   6.031972   8.144719
# 10  2.135014  3.283610  4.199175   5.251971   6.985560

# %%
d = {'0': CNRS0, '20': CNRS20, '40': CNRS40, '60' : CNRS60 , '80' : CNRS80 ,'100' : CNRS100 }
#Cnrs 18kvp
CNRS1_18= []
for keys in d:
    CNRS1_18.append(d[keys].at[1,'CNR1s'])    
    #CNRS0.keys()
#print(CNRS0.loc[1, 'CNR1s'] )
#print(CNRS0.at[1,'CNR1s'])
#CNRS1_18.append(CNRS0.at[1,'CNR1s'])
#CNRS1_18.append(CNRS20.at[1,'CNR1s'])
#CNRS1_18.append(CNRS40.at[1,'CNR1s'])
#CNRS1_18.append(CNRS60.at[1,'CNR1s'])
#CNRS1_18.append(CNRS80.at[1,'CNR1s'])
#CNRS1_18.append(CNRS100.at[1,'CNR1s'])
print(CNRS1_18)    
    #df2 = df[df["y"] < 55]
    #df2_x=df2['x'].to_numpy().astype(int)'''
# Out:
# [4.252514, 5.0450153, 6.1785235, 7.148095, 8.426827, 10.086997]

# %%
# 18 KiloVolts
CNRS1_18= []
CNRS2_18= []
CNRS3_18= []
CNRS4_18= []
CNRS5_18= []
for keys in d:
    CNRS1_18.append(d[keys].at[1,'CNR1s']) 
    CNRS2_18.append(d[keys].at[1,'CNR2s'])
    CNRS3_18.append(d[keys].at[1,'CNR3s'])
    CNRS4_18.append(d[keys].at[1,'CNR4s'])
    CNRS5_18.append(d[keys].at[1,'CNR5s'])

# 20 KiloVolts   
CNRS1_20= []
CNRS2_20= []
CNRS3_20= []
CNRS4_20= []
CNRS5_20= []
for keys in d:
    CNRS1_20.append(d[keys].at[2,'CNR1s']) 
    CNRS2_20.append(d[keys].at[2,'CNR2s'])
    CNRS3_20.append(d[keys].at[2,'CNR3s'])
    CNRS4_20.append(d[keys].at[2,'CNR4s'])
    CNRS5_20.append(d[keys].at[2,'CNR5s'])
    
# 22 kiloVOlts
CNRS1_22= []
CNRS2_22= []
CNRS3_22= []
CNRS4_22= []
CNRS5_22= []
for keys in d:
    CNRS1_22.append(d[keys].at[3,'CNR1s']) 
    CNRS2_22.append(d[keys].at[3,'CNR2s'])
    CNRS3_22.append(d[keys].at[3,'CNR3s'])
    CNRS4_22.append(d[keys].at[3,'CNR4s'])
    CNRS5_22.append(d[keys].at[3,'CNR5s'])
    
# 24 kiloVOlts
CNRS1_24= []
CNRS2_24= []
CNRS3_24= []
CNRS4_24= []
CNRS5_24= []
for keys in d:
    CNRS1_24.append(d[keys].at[4,'CNR1s']) 
    CNRS2_24.append(d[keys].at[4,'CNR2s'])
    CNRS3_24.append(d[keys].at[4,'CNR3s'])
    CNRS4_24.append(d[keys].at[4,'CNR4s'])
    CNRS5_24.append(d[keys].at[4,'CNR5s']) 
    
# 26 kiloVOlts
CNRS1_26= []
CNRS2_26= []
CNRS3_26= []
CNRS4_26= []
CNRS5_26= []
for keys in d:
    CNRS1_26.append(d[keys].at[5,'CNR1s']) 
    CNRS2_26.append(d[keys].at[5,'CNR2s'])
    CNRS3_26.append(d[keys].at[5,'CNR3s'])
    CNRS4_26.append(d[keys].at[5,'CNR4s'])
    CNRS5_26.append(d[keys].at[5,'CNR5s'])

# 26 kiloVOlts
CNRS1_26= []
CNRS2_26= []
CNRS3_26= []
CNRS4_26= []
CNRS5_26= []
for keys in d:
    CNRS1_26.append(d[keys].at[6,'CNR1s']) 
    CNRS2_26.append(d[keys].at[6,'CNR2s'])
    CNRS3_26.append(d[keys].at[6,'CNR3s'])
    CNRS4_26.append(d[keys].at[6,'CNR4s'])
    CNRS5_26.append(d[keys].at[6,'CNR5s'])

    
# 28kiloVOlts
CNRS1_28= []
CNRS2_28= []
CNRS3_28= []
CNRS4_28= []
CNRS5_28= []
for keys in d:
    CNRS1_28.append(d[keys].at[7,'CNR1s']) 
    CNRS2_28.append(d[keys].at[7,'CNR2s'])
    CNRS3_28.append(d[keys].at[7,'CNR3s'])
    CNRS4_28.append(d[keys].at[7,'CNR4s'])
    CNRS5_28.append(d[keys].at[7,'CNR5s'])
    
# 30kiloVOlts
CNRS1_30= []
CNRS2_30= []
CNRS3_30= []
CNRS4_30= []
CNRS5_30= []
for keys in d:
    CNRS1_30.append(d[keys].at[8,'CNR1s']) 
    CNRS2_30.append(d[keys].at[8,'CNR2s'])
    CNRS3_30.append(d[keys].at[8,'CNR3s'])
    CNRS4_30.append(d[keys].at[8,'CNR4s'])
    CNRS5_30.append(d[keys].at[8,'CNR5s'])
    
# 35kiloVOlts
CNRS1_35= []
CNRS2_35= []
CNRS3_35= []
CNRS4_35= []
CNRS5_35= []
for keys in d:
    CNRS1_35.append(d[keys].at[9,'CNR1s']) 
    CNRS2_35.append(d[keys].at[9,'CNR2s'])
    CNRS3_35.append(d[keys].at[9,'CNR3s'])
    CNRS4_35.append(d[keys].at[9,'CNR4s'])
    CNRS5_35.append(d[keys].at[9,'CNR5s'])

# %%
Grosores=[0,20,40,60,80,100]

# %%
fig, axs = plt.subplots(1,2, figsize=(20,10))
#fig = plt.figure(figsize=(15,10))
fig.suptitle('Valores de CNR para las calcificaciones dependiendo del porcentaje de tejido adiposo', fontsize= 20)
axs[0].set_title('Voltaje 18 kV', fontsize= 20)
axs[0].plot(Grosores,CNRS1_18, 'o-', label='calcifiaciones 0.16mm')
axs[0].plot(Grosores,CNRS2_18, 'o-', label='calcifiaciones 0.24mm')
axs[0].plot(Grosores,CNRS3_18, 'o-', label='calcifiaciones 0.32mm')
axs[0].plot(Grosores,CNRS4_18, 'o-', label='calcifiaciones 0.40mm')
axs[0].plot(Grosores,CNRS5_18, 'o-', label='calcifiaciones 0.54mm')
axs[0].set_xlabel('Porcentaje tejiposo', fontsize= 15)
axs[0].set_ylabel('Valor de CNR', fontsize= 15)
axs[0].set_xticks(Grosores, Grosores)
axs[0].grid()
axs[0].legend()

axs[1].set_title('Voltaje 20 kV', fontsize= 20)
axs[1].plot(Grosores,CNRS1_20, 'o-', label='calcifiaciones 0.16mm')
axs[1].plot(Grosores,CNRS2_20, 'o-', label='calcifiaciones 0.24mm')
axs[1].plot(Grosores,CNRS3_20, 'o-', label='calcifiaciones 0.32mm')
axs[1].plot(Grosores,CNRS4_20, 'o-', label='calcifiaciones 0.40mm')
axs[1].plot(Grosores,CNRS5_20, 'o-', label='calcifiaciones 0.54mm')
axs[1].set_xlabel('Porcentaje tejiposo', fontsize= 15)
axs[1].set_ylabel('Valor de CNR', fontsize= 15)
axs[1].set_xticks(Grosores, Grosores)
axs[1].grid()
axs[1].legend()
# Out:
# <ipython-input-71-16f00b01ac24>:12: MatplotlibDeprecationWarning: Passing the minor parameter of set_ticks() positionally is deprecated since Matplotlib 3.2; the parameter will become keyword-only two minor releases later.
#   axs[0].set_xticks(Grosores, Grosores)
# <ipython-input-71-16f00b01ac24>:24: MatplotlibDeprecationWarning: Passing the minor parameter of set_ticks() positionally is deprecated since Matplotlib 3.2; the parameter will become keyword-only two minor releases later.
#   axs[1].set_xticks(Grosores, Grosores)

# %%
fig, axs = plt.subplots(1,2, figsize=(20,10))
#fig = plt.figure(figsize=(15,10))
fig.suptitle('Valores de CNR para las calcificaciones dependiendo del porcentaje de tejido adiposo', fontsize= 20)
axs[0].set_title('Voltaje 22 kV', fontsize= 20)
axs[0].plot(Grosores,CNRS1_22, 'o-', label='calcifiaciones 0.16mm')
axs[0].plot(Grosores,CNRS2_22, 'o-', label='calcifiaciones 0.24mm')
axs[0].plot(Grosores,CNRS3_22, 'o-', label='calcifiaciones 0.32mm')
axs[0].plot(Grosores,CNRS4_22, 'o-', label='calcifiaciones 0.40mm')
axs[0].plot(Grosores,CNRS5_22, 'o-', label='calcifiaciones 0.54mm')
axs[0].set_xlabel('Porcentaje tejiposo', fontsize= 15)
axs[0].set_ylabel('Valor de CNR', fontsize= 15)
axs[0].set_xticks(Grosores, Grosores)
axs[0].grid()
axs[0].legend()

axs[1].set_title('Voltaje 24 kV', fontsize= 20)
axs[1].plot(Grosores,CNRS1_24, 'o-', label='calcifiaciones 0.16mm')
axs[1].plot(Grosores,CNRS2_24, 'o-', label='calcifiaciones 0.24mm')
axs[1].plot(Grosores,CNRS3_24, 'o-', label='calcifiaciones 0.32mm')
axs[1].plot(Grosores,CNRS4_24, 'o-', label='calcifiaciones 0.40mm')
axs[1].plot(Grosores,CNRS5_24, 'o-', label='calcifiaciones 0.54mm')
axs[1].set_xlabel('Porcentaje tejiposo', fontsize= 15)
axs[1].set_ylabel('Valor de CNR', fontsize= 15)
axs[1].set_xticks(Grosores, Grosores)
axs[1].grid()
axs[1].legend()
# Out:
# <ipython-input-72-0df22e54f611>:12: MatplotlibDeprecationWarning: Passing the minor parameter of set_ticks() positionally is deprecated since Matplotlib 3.2; the parameter will become keyword-only two minor releases later.
#   axs[0].set_xticks(Grosores, Grosores)
# <ipython-input-72-0df22e54f611>:24: MatplotlibDeprecationWarning: Passing the minor parameter of set_ticks() positionally is deprecated since Matplotlib 3.2; the parameter will become keyword-only two minor releases later.
#   axs[1].set_xticks(Grosores, Grosores)

# %%
fig, axs = plt.subplots(1,2, figsize=(20,10))
#fig = plt.figure(figsize=(15,10))
fig.suptitle('Valores de CNR para las calcificaciones dependiendo del porcentaje de tejido adiposo', fontsize= 20)
axs[0].set_title('Voltaje 26 kV', fontsize= 20)
axs[0].plot(Grosores,CNRS1_26, 'o-', label='calcifiaciones 0.16mm')
axs[0].plot(Grosores,CNRS2_26, 'o-', label='calcifiaciones 0.24mm')
axs[0].plot(Grosores,CNRS3_26, 'o-', label='calcifiaciones 0.32mm')
axs[0].plot(Grosores,CNRS4_26, 'o-', label='calcifiaciones 0.40mm')
axs[0].plot(Grosores,CNRS5_26, 'o-', label='calcifiaciones 0.54mm')
axs[0].set_xlabel('Porcentaje tejiposo', fontsize= 15)
axs[0].set_ylabel('Valor de CNR', fontsize= 15)
axs[0].set_xticks(Grosores, Grosores)
axs[0].grid()
axs[0].legend()

axs[1].set_title('Voltaje 28 kV', fontsize= 20)
axs[1].plot(Grosores,CNRS1_28, 'o-', label='calcifiaciones 0.16mm')
axs[1].plot(Grosores,CNRS2_28, 'o-', label='calcifiaciones 0.24mm')
axs[1].plot(Grosores,CNRS3_28, 'o-', label='calcifiaciones 0.32mm')
axs[1].plot(Grosores,CNRS4_28, 'o-', label='calcifiaciones 0.40mm')
axs[1].plot(Grosores,CNRS5_28, 'o-', label='calcifiaciones 0.54mm')
axs[1].set_xlabel('Porcentaje tejiposo', fontsize= 15)
axs[1].set_ylabel('Valor de CNR', fontsize= 15)
axs[1].set_xticks(Grosores, Grosores)
axs[1].grid()
axs[1].legend()
# Out:
# <ipython-input-73-a19ffd0e2056>:12: MatplotlibDeprecationWarning: Passing the minor parameter of set_ticks() positionally is deprecated since Matplotlib 3.2; the parameter will become keyword-only two minor releases later.
#   axs[0].set_xticks(Grosores, Grosores)
# <ipython-input-73-a19ffd0e2056>:24: MatplotlibDeprecationWarning: Passing the minor parameter of set_ticks() positionally is deprecated since Matplotlib 3.2; the parameter will become keyword-only two minor releases later.
#   axs[1].set_xticks(Grosores, Grosores)

# %%
fig, axs = plt.subplots(1,2, figsize=(20,10))
#fig = plt.figure(figsize=(15,10))
fig.suptitle('Valores de CNR para las calcificaciones dependiendo del porcentaje de tejido adiposo', fontsize= 20)
axs[0].set_title('Voltaje 30 kV', fontsize= 20)
axs[0].plot(Grosores,CNRS1_30, 'o-', label='calcifiaciones 0.16mm')
axs[0].plot(Grosores,CNRS2_30, 'o-', label='calcifiaciones 0.24mm')
axs[0].plot(Grosores,CNRS3_30, 'o-', label='calcifiaciones 0.32mm')
axs[0].plot(Grosores,CNRS4_30, 'o-', label='calcifiaciones 0.40mm')
axs[0].plot(Grosores,CNRS5_30, 'o-', label='calcifiaciones 0.54mm')
axs[0].set_xlabel('Porcentaje tejiposo', fontsize= 15)
axs[0].set_ylabel('Valor de CNR', fontsize= 15)
axs[0].set_xticks(Grosores, Grosores)
axs[0].grid()
axs[0].legend()

axs[1].set_title('Voltaje 35 kV', fontsize= 20)
axs[1].plot(Grosores,CNRS1_35, 'o-', label='calcifiaciones 0.16mm')
axs[1].plot(Grosores,CNRS2_35, 'o-', label='calcifiaciones 0.24mm')
axs[1].plot(Grosores,CNRS3_35, 'o-', label='calcifiaciones 0.32mm')
axs[1].plot(Grosores,CNRS4_35, 'o-', label='calcifiaciones 0.40mm')
axs[1].plot(Grosores,CNRS5_35, 'o-', label='calcifiaciones 0.54mm')
axs[1].set_xlabel('Porcentaje tejiposo', fontsize= 15)
axs[1].set_ylabel('Valor de CNR', fontsize= 15)
axs[1].set_xticks(Grosores, Grosores)
axs[1].grid()
axs[1].legend()
# Out:
# <ipython-input-80-5ff14648ad05>:12: MatplotlibDeprecationWarning: Passing the minor parameter of set_ticks() positionally is deprecated since Matplotlib 3.2; the parameter will become keyword-only two minor releases later.
#   axs[0].set_xticks(Grosores, Grosores)
# <ipython-input-80-5ff14648ad05>:24: MatplotlibDeprecationWarning: Passing the minor parameter of set_ticks() positionally is deprecated since Matplotlib 3.2; the parameter will become keyword-only two minor releases later.
#   axs[1].set_xticks(Grosores, Grosores)
